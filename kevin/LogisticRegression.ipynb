# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# read csv file for data set

df = pd.read_csv("../Resources/telecom_customer_churn.csv")
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
#   Monthly Charge Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6        593.30           0.00                        0
# 1           -4.0        542.40          38.33                       10
# 2           73.9        280.85           0.00                        0
# 3           98.0       1237.85           0.00                        0
# 4           83.9        267.40           0.00                        0
#
#   Total Long Distance Charges Total Revenue  Customer Status   Churn Category  \
# 0                      381.51        974.81           Stayed              NaN
# 1                       96.21        610.28           Stayed              NaN
# 2                      134.60        415.45          Churned       Competitor
# 3                      361.66       1599.51          Churned  Dissatisfaction
# 4                       22.14        289.54          Churned  Dissatisfaction
#
#                     Churn Reason
# 0                            NaN
# 1                            NaN
# 2  Competitor had better devices
# 3        Product dissatisfaction
# 4            Network reliability
#
# [5 rows x 38 columns]

# %%
# removed joined from customer category
df = df[df['Customer Status'] != 'Joined']

# %%
# Fill in default values from nan values

df['Churn Category']                    = df['Churn Category'].replace(np.nan,'satisfied')
df['Internet Type']                     = df['Internet Type'].replace(np.nan,'No service')
df['Multiple Lines']                    = df['Multiple Lines'].replace(np.nan,'NO phone Service')
df['Avg Monthly Long Distance Charges'] = df['Avg Monthly Long Distance Charges'].replace(np.nan,0)
df['Avg Monthly GB Download']           = df['Avg Monthly GB Download'].replace(np.nan,0)
df['Multiple Lines']                    = df['Multiple Lines'].replace(np.nan,'No service')
df['Internet Service']                  = df['Internet Service'].replace(np.nan,'No service')
df['Online Security']                   = df['Online Security'].replace(np.nan,'No service')
df['Online Backup']                     = df['Online Backup'].replace(np.nan,'No service')
df['Device Protection Plan']            = df['Device Protection Plan'].replace(np.nan,'No service')
df['Premium Tech Support']              = df['Premium Tech Support'].replace(np.nan,'No service')
df['Streaming TV']                      = df['Streaming TV'].replace(np.nan,'No service')
df['Streaming Music']                   = df['Streaming Music'].replace(np.nan,'No service')
df['Unlimited Data']                    = df['Unlimited Data'].replace(np.nan,'No service')
df['Streaming Movies']                  = df['Streaming Movies'].replace(np.nan,'No service')

# %%
print(df.columns)
df.info()
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6589 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        6589 non-null   object
#  1   Gender                             6589 non-null   object
#  2   Age                                6589 non-null   int64
#  3   Married                            6589 non-null   object
#  4   Number of Dependents               6589 non-null   int64
#  5   City                               6589 non-null   object
#  6   Zip Code                           6589 non-null   int64
#  7   Latitude                           6589 non-null   float64
#  8   Longitude                          6589 non-null   float64
#  9   Number of Referrals                6589 non-null   int64
#  10  Tenure in Months                   6589 non-null   int64
#  11  Offer                              6589 non-null   object
#  12  Phone Service                      6589 non-null   object
#  13  Avg Monthly Long Distance Charges  6589 non-null   float64
#  14  Multiple Lines                     6589 non-null   object
#  15  Internet Service                   6589 non-null   object
#  16  Internet Type                      6589 non-null   object
#  17  Avg Monthly GB Download            6589 non-null   float64
#  18  Online Security                    6589 non-null   object
#  19  Online Backup                      6589 non-null   object
#  20  Device Protection Plan             6589 non-null   object
#  21  Premium Tech Support               6589 non-null   object
#  22  Streaming TV                       6589 non-null   object
#  23  Streaming Movies                   6589 non-null   object
#  24  Streaming Music                    6589 non-null   object
#  25  Unlimited Data                     6589 non-null   object
#  26  Contract                           6589 non-null   object
#  27  Paperless Billing                  6589 non-null   object
#  28  Payment Method                     6589 non-null   object
#  29  Monthly Charge                     6589 non-null   float64
#  30  Total Charges                      6589 non-null   float64
#  31  Total Refunds                      6589 non-null   float64
#  32  Total Extra Data Charges           6589 non-null   int64
#  33  Total Long Distance Charges        6589 non-null   float64
#  34  Total Revenue                      6589 non-null   float64
#  35  Customer Status                    6589 non-null   object
#  36  Churn Category                     6589 non-null   object
#  37  Churn Reason                       1869 non-null   object
# dtypes: float64(9), int64(6), object(23)
# memory usage: 2.0+ MB

# %%
# drop the columns for to desired data set based on discovery and group discussion
df = df.drop(['Customer ID','Churn Reason','Total Refunds','Zip Code','Latitude','Longitude',
            'Paperless Billing','Total Revenue','Total Charges','City','Number of Referrals',
            'Tenure in Months',],axis=1)
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Married', 'Number of Dependents', 'Offer',
#        'Phone Service', 'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Payment Method',
#        'Monthly Charge', 'Total Extra Data Charges',
#        'Total Long Distance Charges', 'Customer Status', 'Churn Category'],
#       dtype='object')

# %%
# drop additional columns for logistic regression model
# lr_df = df.drop(['Avg Monthly Long Distance Charges','Multiple Lines','Device Protection Plan',
#                 'Premium Tech Support','Online Security','Monthly Charge','Total Charges',
#                 'Total Long Distance Charges','Churn Category','Internet Type'],axis=1)

# lr_df.head()

# %%
# Select columns for X_train and dummies for yes no catagorical data
lr_df = df[['Avg Monthly Long Distance Charges', 'Offer','Phone Service', 'Monthly Charge',
                'Customer Status','Total Extra Data Charges']]

# %%
from sklearn.model_selection import train_test_split

X = pd.get_dummies(data=lr_df,columns=['Offer','Phone Service','Customer Status'
                                            ], prefix="new",drop_first = True)

y = df["Customer Status"]
print(X.shape, y.shape)
y.dtype

print(X)
# Out:
# (6589, 10) (6589,)
#       Avg Monthly Long Distance Charges  Monthly Charge  \
# 0                                 42.39           65.60
# 1                                 10.69           -4.00
# 2                                 33.65           73.90
# 3                                 27.82           98.00
# 4                                  7.38           83.90
# ...                                 ...             ...
# 7037                               2.01           20.95
# 7038                              46.68           55.15
# 7039                              16.20           85.10
# 7041                               2.12           67.85
# 7042                               0.00           59.00
#
#       Total Extra Data Charges  new_Offer A  new_Offer B  new_Offer C  \
# 0                            0            0            0            0
# 1                           10            0            0            0
# 2                            0            0            0            0
# 3                            0            0            0            0
# 4                            0            0            0            0
# ...                        ...          ...          ...          ...
# 7037                         0            0            0            0
# 7038                         0            0            0            0
# 7039                         0            0            0            0
# 7041                         0            1            0            0
# 7042                         0            0            0            0
#
#       new_Offer D  new_Offer E  new_Yes  new_Stayed
# 0               0            0        1           1
# 1               0            0        1           1
# 2               0            1        1           0
# 3               1            0        1           0
# 4               0            0        1           0
# ...           ...          ...      ...         ...
# 7037            0            0        1           0
# 7038            1            0        1           1
# 7039            1            0        1           0
# 7041            0            0        1           1
# 7042            0            0        0           1
#
# [6589 rows x 10 columns]

# %% [markdown]
# https://www.nickmccullum.com/python-machine-learning/logistic-regression-python/#adding-dummy-variables-to-the-pandas-dataframe

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print (X_train)
# Out:
#       Avg Monthly Long Distance Charges  Monthly Charge  \
# 4541                              21.03           55.30
# 4976                              22.83           85.45
# 3547                              41.16           44.75
# 6646                              32.08           44.70
# 516                               31.31           91.25
# ...                                 ...             ...
# 4037                              21.64           99.65
# 5552                              41.37           75.55
# 5589                              30.31           19.55
# 5760                               5.60           63.95
# 909                               41.74           98.40
#
#       Total Extra Data Charges  new_Offer A  new_Offer B  new_Offer C  \
# 4541                         0            0            0            0
# 4976                         0            1            0            0
# 3547                        10            0            0            0
# 6646                         0            0            0            0
# 516                          0            0            1            0
# ...                        ...          ...          ...          ...
# 4037                         0            0            1            0
# 5552                         0            0            0            0
# 5589                         0            0            1            0
# 5760                         0            0            0            0
# 909                          0            0            0            0
#
#       new_Offer D  new_Offer E  new_Yes  new_Stayed
# 4541            0            0        1           1
# 4976            0            0        1           1
# 3547            0            0        1           0
# 6646            0            0        1           0
# 516             0            0        1           1
# ...           ...          ...      ...         ...
# 4037            0            0        1           1
# 5552            0            0        1           0
# 5589            0            0        1           1
# 5760            0            0        1           1
# 909             0            0        1           0
#
# [4941 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder, MinMaxScaler

# zcale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Train the model

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)

print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 1.0

# %%
predictions = model.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Churned' 'Stayed' 'Stayed' 'Stayed' 'Stayed' 'Stayed' 'Churned' 'Stayed'
#  'Stayed' 'Stayed']
# First 10 Actual labels: ['Churned', 'Stayed', 'Stayed', 'Stayed', 'Stayed', 'Stayed', 'Churned', 'Stayed', 'Stayed', 'Stayed']

# %%
# create dataframe from predictions
predictions = model.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#      Prediction   Actual
# 0       Churned  Churned
# 1        Stayed   Stayed
# 2        Stayed   Stayed
# 3        Stayed   Stayed
# 4        Stayed   Stayed
# ...         ...      ...
# 1643     Stayed   Stayed
# 1644     Stayed   Stayed
# 1645     Stayed   Stayed
# 1646    Churned  Churned
# 1647     Stayed   Stayed
#
# [1648 rows x 2 columns]

# %% [markdown]
# https://towardsdatascience.com/tuning-the-hyperparameters-of-your-machine-learning-model-using-gridsearchcv-7fc2bb76ff27

# %%
# # Hyperparameter Tuning by Creating the GridSearchCV model - here for reference as score is 1
from sklearn.model_selection import GridSearchCV

param_grid = {'C': np.logspace(-3,3,7),
              'solver'  : ['newton-cg', 'lbfgs', 'liblinear'],
            'max_iter':[1000],}

grid = GridSearchCV(model, param_grid, verbose=3)

grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [CV 1/5] END C=0.001, max_iter=1000, solver=newton-cg;, score=0.998 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, solver=newton-cg;, score=0.999 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, solver=lbfgs;, score=0.998 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, solver=lbfgs;, score=0.999 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.1s
# [CV 2/5] END C=0.1, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.3s
# [CV 5/5] END C=0.1, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 2/5] END C=1.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=10.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 2/5] END C=10.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=10.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=10.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.1s
# [CV 5/5] END C=10.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.1s
# [CV 1/5] END C=10.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 2/5] END C=10.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.5s
# [CV 3/5] END C=10.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=10.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/5] END C=10.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=10.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=10.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=10.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=10.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=10.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=100.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.2s
# [CV 2/5] END C=100.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 3/5] END C=100.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=100.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.1s
# [CV 5/5] END C=100.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 1/5] END C=100.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.3s
# [CV 2/5] END C=100.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=100.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 4/5] END C=100.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 5/5] END C=100.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.5s
# [CV 1/5] END C=100.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=100.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=100.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=100.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=100.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1000.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.3s
# [CV 2/5] END C=1000.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.5s
# [CV 3/5] END C=1000.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1000.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1000.0, max_iter=1000, solver=newton-cg;, score=1.000 total time=   0.1s
# [CV 1/5] END C=1000.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1000.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1000.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1000.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1000.0, max_iter=1000, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1000.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1000.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1000.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 4/5] END C=1000.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1000.0, max_iter=1000, solver=liblinear;, score=1.000 total time=   0.0s
# {'C': 0.001, 'max_iter': 1000, 'solver': 'liblinear'}
# 1.0

# %%
# create classifcation report
# from sklearn.metrics import classification_report
# classification_report(y_test, predictions)

# %%
# save model

import joblib
filename = 'LogisticRegression.sav'
joblib.dump(model, filename)
# Out:
# ['LogisticRegression.sav']
